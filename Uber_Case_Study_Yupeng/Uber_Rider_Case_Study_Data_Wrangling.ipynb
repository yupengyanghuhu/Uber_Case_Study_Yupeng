# %% [markdown]
# <center><h1> Uber Rider Data Case Study (part 1)</h1></center>
#
# <center><h2>Yupeng Yang</h2></center>
# <center><h2>Jan 21, 2019</h2></center>

# %% [markdown]
# ##  Project overview
#
# Uber is interested in predicting rider retention. To help explore this question, they have provided a sample dataset of a cohort of users who signed up for an account in <b>January 2014</b>. The data was pulled several months later (06/30/2014).
#
# ## Dataset description
#
# - city: city this user signed up in
# - phone: primary device for this user
# - signup_date: date of account registration; in the form ‘YYYY­MM­DD’
# - last_trip_date: the last time this user completed a trip; in the form ‘YYYY­MM­DD’
# - avg_dist: the average distance *(in miles) per trip taken in the first 30 days after signup
# - avg_rating_by_driver: the rider’s average rating over all of their trips
# - avg_rating_of_driver: the rider’s average rating of their drivers over all of their trips
# - surge_pct: the percent of trips taken with surge multiplier > 1
# - avg_surge: The average surge multiplier over all of this user’s trips
# - trips_in_first_30_days: the number of trips this user took in the first 30 days after signing up
# - luxury_car_user: True if the user took an luxury car in their first 30 days; False otherwise
# - weekday_pct: the percent of the user’s trips occurring during a weekday

# %% [markdown]
# ## 1. Load data and browse data

# %%
# Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# This statement allow to display plot without asking to
# %matplotlib inline

# Always make it pretty.
plt.style.use('ggplot')

# %%
# Load data from file
df = pd.read_csv('data/raw_data.csv')

# %%
# Inspect dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      49799 non-null float64
# avg_rating_of_driver      41878 non-null float64
# avg_surge                 50000 non-null float64
# city                      50000 non-null object
# last_trip_date            50000 non-null object
# phone                     49604 non-null object
# signup_date               50000 non-null object
# surge_pct                 50000 non-null float64
# trips_in_first_30_days    50000 non-null int64
# luxury_car_user           50000 non-null bool
# weekday_pct               50000 non-null float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.2+ MB

# %%
# Browse dataset
df.head(10)
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
# 5     10.56                   5.0                   3.5       1.00
# 6      3.95                   4.0                   NaN       1.00
# 7      2.04                   5.0                   5.0       1.00
# 8      4.36                   5.0                   4.5       1.00
# 9      2.37                   5.0                   NaN       1.00
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
# 5      Winterfell     2014-06-06   iPhone  2014-01-09        0.0
# 6         Astapor     2014-01-25  Android  2014-01-24        0.0
# 7      Winterfell     2014-01-29   iPhone  2014-01-28        0.0
# 8      Winterfell     2014-02-01  Android  2014-01-21        0.0
# 9      Winterfell     2014-01-05  Android  2014-01-03        0.0
#
#    trips_in_first_30_days  luxury_car_user  weekday_pct
# 0                       4             True         46.2
# 1                       0            False         50.0
# 2                       3            False        100.0
# 3                       9             True         80.0
# 4                      14            False         82.4
# 5                       2             True        100.0
# 6                       1            False        100.0
# 7                       2            False        100.0
# 8                       2            False        100.0
# 9                       1            False          0.0

# %%
# Show summary stats
df.describe()
# Out:
#            avg_dist  avg_rating_by_driver  avg_rating_of_driver     avg_surge  \
# count  50000.000000          49799.000000          41878.000000  50000.000000
# mean       5.796827              4.778158              4.601559      1.074764
# std        5.707357              0.446652              0.617338      0.222336
# min        0.000000              1.000000              1.000000      1.000000
# 25%        2.420000              4.700000              4.300000      1.000000
# 50%        3.880000              5.000000              4.900000      1.000000
# 75%        6.940000              5.000000              5.000000      1.050000
# max      160.960000              5.000000              5.000000      8.000000
#
#           surge_pct  trips_in_first_30_days   weekday_pct
# count  50000.000000            50000.000000  50000.000000
# mean       8.849536                2.278200     60.926084
# std       19.958811                3.792684     37.081503
# min        0.000000                0.000000      0.000000
# 25%        0.000000                0.000000     33.300000
# 50%        0.000000                1.000000     66.700000
# 75%        8.600000                3.000000    100.000000
# max      100.000000              125.000000    100.000000

# %%
# Count missing values by column
df.isnull().sum()
# Out:
# avg_dist                     0
# avg_rating_by_driver       201
# avg_rating_of_driver      8122
# avg_surge                    0
# city                         0
# last_trip_date               0
# phone                      396
# signup_date                  0
# surge_pct                    0
# trips_in_first_30_days       0
# luxury_car_user              0
# weekday_pct                  0
# dtype: int64

# %% [markdown]
# ## 2.Explore data (EDA)

# %% [markdown]
# ### -- For Numeric variables:
# deal with avgerage distance, average surge, surge pct, week pct, rate of/by driver, first 30 day trips count

# %%
df['avg_dist'].plot.hist(bins=20)

# %%
df['avg_surge'].plot.hist(bins=20)

# %%
df['surge_pct'].plot.hist(bins=20)

# %%
df['weekday_pct'].plot.hist(bins=20)

# %%
df['avg_rating_by_driver'].plot.hist(bins=20)

# %%
df['avg_rating_of_driver'].plot.hist(bins=20)

# %%
df['trips_in_first_30_days'].plot.hist(bins=20)

# %%
# Use scatter_matrix from Pandas
from pandas.plotting import scatter_matrix
scatter_matrix(df[[u'avg_dist', u'trips_in_first_30_days', u'weekday_pct']], 
               alpha=0.2, figsize=(8, 8), diagonal='kde')
plt.show()

# %% [markdown]
# ### -- For Categorical variables:
# city, phone types, luxury car user

# %%
df['city'].value_counts()
# Out:
# Winterfell        23336
# Astapor           16534
# King's Landing    10130
# Name: city, dtype: int64

# %%
df['city'].value_counts().plot.bar()

# %%
df['phone'].value_counts()
# Out:
# iPhone     34582
# Android    15022
# Name: phone, dtype: int64

# %%
df['phone'].value_counts(dropna=False).plot.bar()

# %%
df['luxury_car_user'].value_counts().plot.bar()

# %% [markdown]
# ## 3. Clean data - dealing with missing values

# %%
# Count missing values by column
df.isnull().sum()
# Out:
# avg_dist                     0
# avg_rating_by_driver       201
# avg_rating_of_driver      8122
# avg_surge                    0
# city                         0
# last_trip_date               0
# phone                      396
# signup_date                  0
# surge_pct                    0
# trips_in_first_30_days       0
# luxury_car_user              0
# weekday_pct                  0
# dtype: int64

# %% [markdown]
# #### Option 1: drop all rows that have missing values

# %%
df_dropna = df.dropna(axis=0) # 0 is for rows

# %%
df_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41445 entries, 0 to 49998
# Data columns (total 12 columns):
# avg_dist                  41445 non-null float64
# avg_rating_by_driver      41445 non-null float64
# avg_rating_of_driver      41445 non-null float64
# avg_surge                 41445 non-null float64
# city                      41445 non-null object
# last_trip_date            41445 non-null object
# phone                     41445 non-null object
# signup_date               41445 non-null object
# surge_pct                 41445 non-null float64
# trips_in_first_30_days    41445 non-null int64
# luxury_car_user           41445 non-null bool
# weekday_pct               41445 non-null float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_dropna.describe()
# Out:
#            avg_dist  avg_rating_by_driver  avg_rating_of_driver     avg_surge  \
# count  41445.000000          41445.000000          41445.000000  41445.000000
# mean       5.460046              4.776446              4.601720      1.073822
# std        5.145174              0.404606              0.616104      0.198747
# min        0.000000              1.000000              1.000000      1.000000
# 25%        2.420000              4.700000              4.300000      1.000000
# 50%        3.780000              5.000000              4.900000      1.000000
# 75%        6.490000              5.000000              5.000000      1.070000
# max       79.690000              5.000000              5.000000      8.000000
#
#           surge_pct  trips_in_first_30_days   weekday_pct
# count  41445.000000            41445.000000  41445.000000
# mean       8.898709                2.609675     61.254897
# std       18.322061                4.059336     34.813848
# min        0.000000                0.000000      0.000000
# 25%        0.000000                0.000000     37.500000
# 50%        0.000000                1.000000     66.700000
# 75%       11.100000                3.000000    100.000000
# max      100.000000              125.000000    100.000000

# %% [markdown]
# #### Option 2: fill missing values

# %%
# Make a copy of df, because you don't want to mess up with orignal df when you experiment stuff
df_fillna = df.copy()

# %%
# Fill missing value for phone
df_fillna['phone'] = df['phone'].fillna('no_phone') #Can see there are NaNs in the above graph

# %%
# Fill missing values with median
df_fillna['avg_rating_by_driver'] = df['avg_rating_by_driver'].fillna(df['avg_rating_by_driver'].median())
df_fillna['avg_rating_of_driver'] = df['avg_rating_of_driver'].fillna(df['avg_rating_of_driver'].median())

# %%
df_fillna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      50000 non-null float64
# avg_rating_of_driver      50000 non-null float64
# avg_surge                 50000 non-null float64
# city                      50000 non-null object
# last_trip_date            50000 non-null object
# phone                     50000 non-null object
# signup_date               50000 non-null object
# surge_pct                 50000 non-null float64
# trips_in_first_30_days    50000 non-null int64
# luxury_car_user           50000 non-null bool
# weekday_pct               50000 non-null float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.2+ MB

# %%
df_fillna.describe()
# Out:
#            avg_dist  avg_rating_by_driver  avg_rating_of_driver     avg_surge  \
# count  50000.000000          50000.000000          50000.000000  50000.000000
# mean       5.796827              4.779050              4.650038      1.074764
# std        5.707357              0.445974              0.575601      0.222336
# min        0.000000              1.000000              1.000000      1.000000
# 25%        2.420000              4.700000              4.500000      1.000000
# 50%        3.880000              5.000000              4.900000      1.000000
# 75%        6.940000              5.000000              5.000000      1.050000
# max      160.960000              5.000000              5.000000      8.000000
#
#           surge_pct  trips_in_first_30_days   weekday_pct
# count  50000.000000            50000.000000  50000.000000
# mean       8.849536                2.278200     60.926084
# std       19.958811                3.792684     37.081503
# min        0.000000                0.000000      0.000000
# 25%        0.000000                0.000000     33.300000
# 50%        0.000000                1.000000     66.700000
# 75%        8.600000                3.000000    100.000000
# max      100.000000              125.000000    100.000000

# %% [markdown]
# #### Decision
# We decide to exclude data with imputation value.

# %%
df = df_fillna
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  luxury_car_user  weekday_pct
# 0                       4             True         46.2
# 1                       0            False         50.0
# 2                       3            False        100.0
# 3                       9             True         80.0
# 4                      14            False         82.4

# %% [markdown]
# ## Transform data

# %% [markdown]
# ### Time-series variables

# %%
# convert time-series information to datetime data type
df['last_trip_date'] = pd.to_datetime(df['last_trip_date'])
df['signup_date'] = pd.to_datetime(df['signup_date'])
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  luxury_car_user  weekday_pct
# 0                       4             True         46.2
# 1                       0            False         50.0
# 2                       3            False        100.0
# 3                       9             True         80.0
# 4                      14            False         82.4

# %%
# construct a new df to experiment on the time-series 
df_timestamp = df[['last_trip_date', 'signup_date']].copy()
df_timestamp.head()
# Out:
#   last_trip_date signup_date
# 0     2014-06-17  2014-01-25
# 1     2014-05-05  2014-01-29
# 2     2014-01-07  2014-01-06
# 3     2014-06-29  2014-01-10
# 4     2014-03-15  2014-01-27

# %%
df_timestamp['count'] = 1
df_timestamp.head()
# Out:
#   last_trip_date signup_date  count
# 0     2014-06-17  2014-01-25      1
# 1     2014-05-05  2014-01-29      1
# 2     2014-01-07  2014-01-06      1
# 3     2014-06-29  2014-01-10      1
# 4     2014-03-15  2014-01-27      1

# %%
df_timestamp = df_timestamp.set_index('signup_date')
df_timestamp['count'].resample("1D").sum().plot()

# %%
df_timestamp = df_timestamp.set_index('last_trip_date')
df_timestamp['count'].resample("1D").sum().plot() # ‘1D’ is 1 day

# %%
# Experiment block
date_in_string = '2014-06-01'
date_in_datetime = pd.to_datetime(date_in_string)
print(date_in_datetime)
print(date_in_datetime.dayofweek)
pd.to_datetime('2014-06-30') - pd.to_datetime('2014-06-21') #just try
# Out:
# 2014-06-01 00:00:00
# 6
# Timedelta('9 days 00:00:00')

# %%
# There might be some signal from day of week when a user signed up Uber, so let's create a column for that
df['signup_dow'] = df['signup_date'].apply(lambda x: x.dayofweek)

# %%
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  luxury_car_user  weekday_pct  signup_dow
# 0                       4             True         46.2           5
# 1                       0            False         50.0           2
# 2                       3            False        100.0           0
# 3                       9             True         80.0           4
# 4                      14            False         82.4           0

# %% [markdown]
# ### Converting categorical variables by one hot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      50000 non-null float64
# avg_rating_of_driver      50000 non-null float64
# avg_surge                 50000 non-null float64
# city                      50000 non-null object
# last_trip_date            50000 non-null datetime64[ns]
# phone                     50000 non-null object
# signup_date               50000 non-null datetime64[ns]
# surge_pct                 50000 non-null float64
# trips_in_first_30_days    50000 non-null int64
# luxury_car_user           50000 non-null bool
# weekday_pct               50000 non-null float64
# signup_dow                50000 non-null int64
# dtypes: bool(1), datetime64[ns](2), float64(6), int64(2), object(2)
# memory usage: 4.6+ MB

# %% [markdown]
# Categorical variables:
# * city
# * phone
# * luxury_car_user: to 0 / 1
# * signup_dow

# %% [markdown]
# #### Convert bool columns to int

# %%
df['luxury_car_user'] = df['luxury_car_user'].astype(int)

# %%
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days       ...        signup_dow_3  signup_dow_4  \
# 0                       4       ...                   0             0
# 1                       0       ...                   0             0
# 2                       3       ...                   0             0
# 3                       9       ...                   0             1
# 4                      14       ...                   0             0
#
#    signup_dow_5  signup_dow_6  city_Astapor  city_King's Landing  \
# 0             1             0             0                    1
# 1             0             0             1                    0
# 2             0             0             1                    0
# 3             0             0             0                    1
# 4             0             0             0                    0
#
#    city_Winterfell  phone_Android  phone_iPhone  phone_no_phone
# 0                0              0             1               0
# 1                0              1             0               0
# 2                0              0             1               0
# 3                0              0             1               0
# 4                1              1             0               0
#
# [5 rows x 26 columns]

# %%
df.columns ###
# Out:
# Index(['avg_dist', 'avg_rating_by_driver', 'avg_rating_of_driver', 'avg_surge',
#        'city', 'last_trip_date', 'phone', 'signup_date', 'surge_pct',
#        'trips_in_first_30_days', 'luxury_car_user', 'weekday_pct',
#        'signup_dow', 'signup_dow_0', 'signup_dow_1', 'signup_dow_2',
#        'signup_dow_3', 'signup_dow_4', 'signup_dow_5', 'signup_dow_6',
#        'city_Astapor', 'city_King's Landing', 'city_Winterfell',
#        'phone_Android', 'phone_iPhone', 'phone_no_phone'],
#       dtype='object')

# %% [markdown]
# ## 4. Define a label/target/outcome
#
# Add churn indicator. Considered to <b>churn if have not taken a trip in the last 30 days</b>. In practice, you will often have to figure out how to generate a reasonable label to train your dataset. ***Is the cutoff of 30 days reasonable?  You may want to test this... Sometimes, the correct label is even less obvious; your ability to make a sensible (and defensible) decision in these cases is important.

# %%
# Define churn: users did not take a trip during last 30 days, i.e. last trip date is earlier than 2014-06-01
df['churn'] = (df.last_trip_date < pd.to_datetime('2014-06-01')) * 1
df['active'] = (df.last_trip_date >= pd.to_datetime('2014-06-01')) * 1

df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days   ...    signup_dow_5  signup_dow_6  city_Astapor  \
# 0                       4   ...               1             0             0
# 1                       0   ...               0             0             1
# 2                       3   ...               0             0             1
# 3                       9   ...               0             0             0
# 4                      14   ...               0             0             0
#
#    city_King's Landing  city_Winterfell  phone_Android  phone_iPhone  \
# 0                    1                0              0             1
# 1                    0                0              1             0
# 2                    0                0              0             1
# 3                    1                0              0             1
# 4                    0                1              1             0
#
#    phone_no_phone  churn  active
# 0               0      0       1
# 1               0      1       0
# 2               0      1       0
# 3               0      0       1
# 4               0      1       0
#
# [5 rows x 28 columns]

# %%
df['churn'].mean() #too many rider give up...
# Out:
# 0.62392

# %%
df['active'].mean()
# Out:
# 0.37608

# %% [markdown]
# ## EDA with label

# %% [markdown]
# ### colored scatter_matrix

# %%
colors = ['red' if ix else 'blue' for ix in df['active']]

# %%
# scatter_matrix(df[[u'avg_dist', u'avg_rating_by_driver', u'avg_rating_of_driver', 
#                   u'avg_surge', u'surge_pct', u'trips_in_first_30_days', u'weekday_pct']],
#                alpha=0.2, figsize=(16, 16), diagonal='hist', c=colors)
# plt.show()

# %% [markdown]
# ### Explore churn rate split by features

# %%
df[['city', 'churn']].groupby(['city']).mean().plot.bar()

# %%
df[['phone', 'churn']].groupby(['phone']).mean().plot.bar()

# %%
df[['luxury_car_user', 'active']].groupby(['luxury_car_user']).mean().plot.bar()

# %%
df[['trips_in_first_30_days', 'active']].groupby(['active']).mean().plot.bar()

# %%
is_active = df['active'] == 1

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].hist(df[is_active]['avg_dist'].values)
axes[1].hist(df[~is_active]['avg_dist'].values)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Abstract out the plotting machine

# %%
def hist_active_vs_churn(df, col_name):
    is_active = df['active'] == 1
    fig, axes = plt.subplots(nrows=1, ncols=2)
    axes[0].hist(df[is_active][col_name].values)
    axes[0].set_title("active users")
    axes[0].set_xlabel(col_name)
    axes[0].set_ylabel("counts")
    axes[1].hist(df[~is_active][col_name].values)
    axes[1].set_title("churned users")
    axes[1].set_xlabel(col_name)
    axes[1].set_ylabel("counts")
    fig.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['avg_dist', 'avg_rating_by_driver', 'avg_rating_of_driver', 'avg_surge',
#        'city', 'last_trip_date', 'phone', 'signup_date', 'surge_pct',
#        'trips_in_first_30_days', 'luxury_car_user', 'weekday_pct',
#        'signup_dow', 'signup_dow_0', 'signup_dow_1', 'signup_dow_2',
#        'signup_dow_3', 'signup_dow_4', 'signup_dow_5', 'signup_dow_6',
#        'city_Astapor', 'city_King's Landing', 'city_Winterfell',
#        'phone_Android', 'phone_iPhone', 'phone_no_phone', 'churn', 'active'],
#       dtype='object')

# %%
hist_active_vs_churn(df, col_name=u'avg_rating_by_driver')

# %%
cols = [u'avg_dist', u'avg_rating_by_driver', u'avg_rating_of_driver', u'avg_surge']

# %%
for col in cols:
    hist_active_vs_churn(df, col_name=col)

# %% [markdown]
# ## Save cleaned data to csv file

# %% [markdown]
# ### Select which columns to be saved

# %%
selected_columns = [u'avg_dist', u'avg_rating_by_driver', u'avg_rating_of_driver', u'avg_surge', 
                     u'surge_pct', u'trips_in_first_30_days', u'luxury_car_user', 
                     u'weekday_pct', u'city_Astapor', u'city_King\'s Landing',u'city_Winterfell', 
                     u'phone_Android', u'phone_iPhone', u'phone_no_phone', u'signup_dow_0', 
                     u'signup_dow_1', u'signup_dow_2', u'signup_dow_3', u'signup_dow_4', 
                     u'signup_dow_5', u'signup_dow_6', u'churn']

# %% [markdown]
# ### Save to csv file

# %%
cleaned_data_csv = 'data/cleaned_data.csv'
df[selected_columns].to_csv(cleaned_data_csv, index=False)
